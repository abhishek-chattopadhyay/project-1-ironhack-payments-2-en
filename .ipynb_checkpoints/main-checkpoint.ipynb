# %% [markdown]
# ### Import all the libraries here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Read data here

# %%
fees = pd.read_csv("./project_dataset/extract - fees - data analyst - .csv")
cash_req = pd.read_csv("./project_dataset/extract - cash request - data analyst.csv")

df_fees = fees.copy()
df_cash_req = cash_req.copy()

# %% [markdown]
# ### Go through your data here

# %%
df_fees.head(10)
# Out:
#       id  cash_request_id             type     status               category  \
# 0   6537          14941.0  instant_payment   rejected                    NaN
# 1   6961          11714.0         incident   accepted  rejected_direct_debit
# 2  16296          23371.0  instant_payment   accepted                    NaN
# 3  20775          26772.0  instant_payment   accepted                    NaN
# 4  11242          19350.0  instant_payment   accepted                    NaN
# 5  17029          24052.0  instant_payment   accepted                    NaN
# 6  19956          25983.0  instant_payment   accepted                    NaN
# 7  14187          14839.0         incident   accepted  rejected_direct_debit
# 8  20539          26572.0  instant_payment   accepted                    NaN
# 9  15431          22106.0         postpone  cancelled                    NaN
#
#    total_amount                              reason  \
# 0           5.0  Instant Payment Cash Request 14941
# ...

# %%
df_fees["id"].is_unique
# Out:
# True

# %%
df_fees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21061 entries, 0 to 21060
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21061 non-null  int64
#  1   cash_request_id  21057 non-null  float64
#  2   type             21061 non-null  object
#  3   status           21061 non-null  object
#  4   category         2196 non-null   object
#  5   total_amount     21061 non-null  float64
#  6   reason           21061 non-null  object
#  7   created_at       21061 non-null  object
#  8   updated_at       21061 non-null  object
#  9   paid_at          15531 non-null  object
#  10  from_date        7766 non-null   object
#  11  to_date          7766 non-null   object
#  12  charge_moment    21061 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.1+ MB

# %%
df_fees.shape
# Out:
# (21061, 13)

# %%
df_cash_req.head(10)
# Out:
#      id  amount      status                     created_at  \
# 0     5   100.0    rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0    rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0    rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0    rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0    rejected  2020-05-06 09:59:38.877376+00
# 5  2145   100.0  money_back  2020-05-23 20:58:55.129432+00
# 6  3512   100.0    rejected  2020-06-16 17:07:38.452652+00
# 7   654   100.0    rejected   2020-02-10 01:11:53.80827+00
# 8  5672   100.0    canceled   2020-06-28 12:06:33.71284+00
# 9    71    90.0    rejected  2019-12-10 19:51:23.911206+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# ...

# %%
df_cash_req.tail(10)
# Out:
#           id  amount             status                     created_at  \
# 23960  26969    50.0  direct_debit_sent  2020-11-01 17:31:03.345533+00
# 23961  18579   100.0         money_back  2020-09-30 14:28:32.645872+00
# 23962  26979   100.0         money_back  2020-11-01 19:08:24.111371+00
# 23963   7930   100.0         money_back  2020-07-14 08:55:09.360786+00
# 23964  16834   100.0         money_back  2020-09-19 07:37:14.351567+00
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at   user_id                   moderated_at  \
# 23960  2021-01-06 09:07:31.575691+00    3377.0                            NaN
# ...

# %%
df_cash_req.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          23970 non-null  int64
#  1   amount                      23970 non-null  float64
#  2   status                      23970 non-null  object
#  3   created_at                  23970 non-null  object
#  4   updated_at                  23970 non-null  object
#  5   user_id                     21867 non-null  float64
#  6   moderated_at                16035 non-null  object
#  7   deleted_account_id          2104 non-null   float64
#  8   reimbursement_date          23970 non-null  object
#  9   cash_request_received_date  16289 non-null  object
#  10  money_back_date             16543 non-null  object
#  11  transfer_type               23970 non-null  object
#  12  send_at                     16641 non-null  object
# ...

# %%
df_cash_req.shape
# Out:
# (23970, 16)

# %%
df_cash_req["status"].value_counts()
# Out:
# status
# money_back               16397
# rejected                  6568
# direct_debit_rejected      831
# active                      59
# transaction_declined        48
# direct_debit_sent           34
# canceled                    33
# Name: count, dtype: int64

# %%
df_cash_req["user_id"].value_counts()
# Out:
# user_id
# 3377.0     19
# 2142.0     18
# 13851.0    18
# 15219.0    17
# 10086.0    17
#            ..
# 89669.0     1
# 83075.0     1
# 821.0       1
# 1248.0      1
# 163.0       1
# Name: count, Length: 10798, dtype: int64

# %%
df_cash_req.groupby("user_id").get_group(3377.0)
# Out:
#           id  amount             status                     created_at  \
# 30      1540   100.0           rejected  2020-05-04 04:23:57.148763+00
# 229      936   100.0           rejected  2020-03-18 08:05:49.092391+00
# 230      830   100.0           rejected  2020-03-09 13:31:06.855375+00
# 251     1369   100.0           rejected  2020-04-24 18:51:10.588402+00
# 408     2243    70.0           rejected  2020-05-28 14:39:45.591884+00
# 443      987   100.0           rejected  2020-03-25 09:12:17.659574+00
# 614     1684    50.0           rejected  2020-05-11 17:08:36.422278+00
# 729     1019    50.0           rejected  2020-04-01 16:26:07.710169+00
# 840     2036    50.0           rejected  2020-05-19 15:52:55.868692+00
# 1582    2819   100.0           rejected  2020-06-09 18:36:00.336349+00
# 1664   11450    50.0           rejected  2020-08-08 06:57:10.590228+00
# 1705    3642   100.0           rejected  2020-06-17 13:56:27.141261+00
# ...

# %%
df_cash_req["created_at"].min()
# Out:
# '2019-11-19 13:57:53.511561+00'

# %%
df_cash_req["created_at"].max()
# Out:
# '2020-11-01 23:42:30.847066+00'

# %%
id_cash = set(df_cash_req["id"])

# %%
id_fees = set(df_fees["cash_request_id"])

# %%
len(id_cash.intersection(id_fees))
# Out:
# 12933

# %%
len(id_cash)
# Out:
# 23970

# %%
len(id_fees)
# Out:
# 12937

# %%
df_fees.head(10)
# Out:
#       id  cash_request_id             type     status               category  \
# 0   6537          14941.0  instant_payment   rejected                    NaN
# 1   6961          11714.0         incident   accepted  rejected_direct_debit
# 2  16296          23371.0  instant_payment   accepted                    NaN
# 3  20775          26772.0  instant_payment   accepted                    NaN
# 4  11242          19350.0  instant_payment   accepted                    NaN
# 5  17029          24052.0  instant_payment   accepted                    NaN
# 6  19956          25983.0  instant_payment   accepted                    NaN
# 7  14187          14839.0         incident   accepted  rejected_direct_debit
# 8  20539          26572.0  instant_payment   accepted                    NaN
# 9  15431          22106.0         postpone  cancelled                    NaN
#
#    total_amount                              reason  \
# 0           5.0  Instant Payment Cash Request 14941
# ...

# %%
df_cash_req.head(10)
# Out:
#      id  amount      status                     created_at  \
# 0     5   100.0    rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0    rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0    rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0    rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0    rejected  2020-05-06 09:59:38.877376+00
# 5  2145   100.0  money_back  2020-05-23 20:58:55.129432+00
# 6  3512   100.0    rejected  2020-06-16 17:07:38.452652+00
# 7   654   100.0    rejected   2020-02-10 01:11:53.80827+00
# 8  5672   100.0    canceled   2020-06-28 12:06:33.71284+00
# 9    71    90.0    rejected  2019-12-10 19:51:23.911206+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# ...

# %%
df_fees["cash_request_id"].isna().sum()
# Out:
# np.int64(4)

# %%
# merging two dataframes
df_fees.drop(columns=["id"], inplace=True)

# %%
df_fees
# Out:
#        cash_request_id             type    status               category  \
# 0              14941.0  instant_payment  rejected                    NaN
# 1              11714.0         incident  accepted  rejected_direct_debit
# 2              23371.0  instant_payment  accepted                    NaN
# 3              26772.0  instant_payment  accepted                    NaN
# 4              19350.0  instant_payment  accepted                    NaN
# ...                ...              ...       ...                    ...
# 21056          20262.0  instant_payment  rejected                    NaN
# 21057          26764.0  instant_payment  rejected                    NaN
# 21058          25331.0  instant_payment  rejected                    NaN
# 21059          23628.0  instant_payment  rejected                    NaN
# 21060          20982.0  instant_payment  accepted                    NaN
#
#        total_amount                              reason  \
# ...

# %%
# merge two tables
df_merge = df_cash_req.merge(df_fees, left_on = "id", right_on = "cash_request_id", how = 'left', suffixes=("_cash", "_fees"))

# %%
df_merge.shape
# Out:
# (32094, 28)

# %%
df_cash_req.shape
# Out:
# (23970, 16)

# %%
df_fees.shape
# Out:
# (21061, 12)

# %%
df_merge.tail(3)
# Out:
#           id  amount        status_cash                created_at_cash  \
# 32091  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 32092  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
# 32093  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                      updated_at_cash  user_id moderated_at  \
# 32091  2021-02-05 13:14:19.707627+00  64517.0          NaN
# 32092  2021-01-05 15:45:52.645536+00  44867.0          NaN
# 32093  2021-01-05 15:45:52.645536+00  44867.0          NaN
#
#        deleted_account_id      reimbursement_date cash_request_received_date  \
# 32091                 NaN  2021-02-05 11:00:00+00                 2020-10-12
# 32092                 NaN  2021-02-05 11:00:00+00                 2020-10-10
# 32093                 NaN  2021-02-05 11:00:00+00                 2020-10-10
#
#        ... status_fees category total_amount  \
# 32091  ...    accepted      NaN          5.0
# ...
