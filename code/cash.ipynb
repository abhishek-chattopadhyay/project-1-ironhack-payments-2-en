# %% [markdown]
# # Import all the libraries here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read data here

# %%
fees = pd.read_csv("/Users/davidthrien/Documents/Ironhack/Ironhack_labs/Week2/Projektarbeit/Ohne Titel/project_dataset/fees - data analyst - .csv")
cash_req = pd.read_csv("/Users/davidthrien/Documents/Ironhack/Ironhack_labs/Week2/Projektarbeit/Ohne Titel/project_dataset/cash request - data analyst.csv")

df_fees = fees.copy()
df_cash_req = cash_req.copy()

# %% [markdown]
# # Explore your data here

# %% [markdown]
# ## cash request file

# %%
df_cash_req.head(10)
# Out:
#      id  amount      status                     created_at  \
# 0     5   100.0    rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0    rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0    rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0    rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0    rejected  2020-05-06 09:59:38.877376+00
# 5  2145   100.0  money_back  2020-05-23 20:58:55.129432+00
# 6  3512   100.0    rejected  2020-06-16 17:07:38.452652+00
# 7   654   100.0    rejected   2020-02-10 01:11:53.80827+00
# 8  5672   100.0    canceled   2020-06-28 12:06:33.71284+00
# 9    71    90.0    rejected  2019-12-10 19:51:23.911206+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# ...

# %%
df_cash_req.tail(10)
# Out:
#           id  amount             status                     created_at  \
# 23960  26969    50.0  direct_debit_sent  2020-11-01 17:31:03.345533+00
# 23961  18579   100.0         money_back  2020-09-30 14:28:32.645872+00
# 23962  26979   100.0         money_back  2020-11-01 19:08:24.111371+00
# 23963   7930   100.0         money_back  2020-07-14 08:55:09.360786+00
# 23964  16834   100.0         money_back  2020-09-19 07:37:14.351567+00
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at   user_id                   moderated_at  \
# 23960  2021-01-06 09:07:31.575691+00    3377.0                            NaN
# ...

# %%
df_cash_req.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          23970 non-null  int64
#  1   amount                      23970 non-null  float64
#  2   status                      23970 non-null  object
#  3   created_at                  23970 non-null  object
#  4   updated_at                  23970 non-null  object
#  5   user_id                     21867 non-null  float64
#  6   moderated_at                16035 non-null  object
#  7   deleted_account_id          2104 non-null   float64
#  8   reimbursement_date          23970 non-null  object
#  9   cash_request_received_date  16289 non-null  object
#  10  money_back_date             16543 non-null  object
#  11  transfer_type               23970 non-null  object
#  12  send_at                     16641 non-null  object
# ...

# %%
df_cash_req.shape
# Out:
# (23970, 16)

# %%
df_cash_req.sample(4)
# Out:
#          id  amount    status                     created_at  \
# 1469   3182   100.0  rejected  2020-06-12 16:59:56.761562+00
# 9719  13565    50.0  rejected  2020-08-22 10:31:46.696464+00
# 4475  12989   100.0  rejected  2020-08-18 19:34:24.834823+00
# 4774  16607   100.0  rejected  2020-09-17 12:37:03.730552+00
#
#                          updated_at  user_id                   moderated_at  \
# 1469  2020-06-13 15:56:12.826669+00  14497.0  2020-06-13 15:56:12.821824+00
# 9719  2020-08-22 14:53:57.342533+00      NaN  2020-08-22 14:53:57.335162+00
# 4475   2020-08-19 10:56:34.69141+00  21449.0  2020-08-19 10:56:34.683937+00
# 4774  2020-09-17 13:12:00.097255+00  13269.0  2020-09-17 13:12:00.089452+00
#
#       deleted_account_id             reimbursement_date  \
# 1469                 NaN         2020-06-29 22:00:00+00
# 9719             21631.0     2020-09-05 10:31:55.053+00
# 4475                 NaN  2020-09-04 19:34:24.792463+00
# ...

# %%
df_cash_req["created_at"].min()
# Out:
# '2019-11-19 13:57:53.511561+00'

# %%
df_cash_req["created_at"].max()
# Out:
# '2020-11-01 23:42:30.847066+00'

# %%
id_cash = set(df_cash_req["id"])

# %%
id_fees = set(df_fees["cash_request_id"])

# %%
len(id_cash.intersection(id_fees))
# Out:
# 12933

# %%
len(id_cash)
# Out:
# 23970

# %%
len(id_fees)
# Out:
# 12937

# %%
df_cash_req.describe().T
# Out:
#                       count          mean           std   min       25%  \
# id                  23970.0  13910.966124   7788.117214   3.0   7427.25
# amount              23970.0     82.720818     26.528065   1.0     50.00
# user_id             21867.0  32581.250789  27618.565773  34.0  10804.00
# deleted_account_id   2104.0   9658.755228   7972.743249  91.0   3767.00
#
#                         50%       75%       max
# id                  14270.5  20607.75   27010.0
# amount                100.0    100.00     200.0
# user_id             23773.0  46965.00  103719.0
# deleted_account_id   6121.5  16345.00   30445.0

# %% [markdown]
# # Clean Data

# %%
def from_dt_to_mon(timestemp):
    return datetime.fromisoformat(timestemp).strftime("%B")[:3]

def from_dt_to_yr(timestemp):
    return datetime.fromisoformat(timestemp).strftime("%Y")

# %%
df_cash_req["month"] = df_cash_req["created_at"].apply(from_dt_to_mon)

# %%
df_cash_req["year"] = df_cash_req["created_at"].apply(from_dt_to_yr)

# %%
df_cash_req
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at  user_id                   moderated_at  \
# ...

# %%
df_cash_req["year"] = df_cash_req["year"].astype(int)

# %%
df_cash_req = df_cash_req[["id", "amount", "status", "created_at", "user_id", "deleted_account_id", "transfer_type", "month", "year"]]
df_cash_req
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#        user_id  deleted_account_id transfer_type month  year
# ...

# %%
sns.histplot(df_cash_req["amount"])
plt.show()

# %%
df_cash_req_2019 = df_cash_req[df_cash_req["year"] == 2019]

# %%
df_cash_req_2019
# Out:
#         id  amount                 status                     created_at  \
# 0        5   100.0               rejected  2019-12-10 19:05:21.596873+00
# 1       70   100.0               rejected   2019-12-10 19:50:12.34778+00
# 2        7   100.0               rejected   2019-12-10 19:13:35.82546+00
# 3       10    99.0               rejected  2019-12-10 19:16:10.880172+00
# 9       71    90.0               rejected  2019-12-10 19:51:23.911206+00
# ...    ...     ...                    ...                            ...
# 10481  196   100.0             money_back  2019-12-17 05:56:02.995177+00
# 10483  129   100.0  direct_debit_rejected  2019-12-12 18:46:44.796372+00
# 10521  304   100.0  direct_debit_rejected  2019-12-24 20:10:37.297594+00
# 10667  119   100.0  direct_debit_rejected  2019-12-12 14:14:23.643863+00
# 10788  151   100.0  direct_debit_rejected  2019-12-13 22:50:37.687507+00
#
#        user_id  deleted_account_id transfer_type month  year
# ...

# %%
df_cash_req_2020 = df_cash_req[df_cash_req["year"] == 2020]
df_cash_req_2020
# Out:
#           id  amount             status                     created_at  \
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# 5       2145   100.0         money_back  2020-05-23 20:58:55.129432+00
# 6       3512   100.0           rejected  2020-06-16 17:07:38.452652+00
# 7        654   100.0           rejected   2020-02-10 01:11:53.80827+00
# 8       5672   100.0           canceled   2020-06-28 12:06:33.71284+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#        user_id  deleted_account_id transfer_type month  year
# ...

# %%
df_cash_req_userid_filled = df_cash_req.copy()

# fill user ID with Deleted Account ID, when empty
df_cash_req_userid_filled["user_id"] = df_cash_req_userid_filled["user_id"].fillna(df_cash_req_userid_filled["deleted_account_id"])
df_cash_req_userid_filled
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#        user_id  deleted_account_id transfer_type month  year
# ...

# %%
df_cash_req_userid_filled.groupby(["year","month"])["user_id"].nunique()
# Out:
# year  month
# 2019  Dec       255
#       Nov         1
# 2020  Apr       421
#       Aug      2599
#       Feb       170
#       Jan       196
#       Jul      2711
#       Jun      2101
#       Mar       215
#       May       730
#       Nov       140
#       Oct      7191
#       Sep      3669
# Name: user_id, dtype: int64

# %%
# group for user id and get combinations for their activity
user_activity = df_cash_req_userid_filled.groupby('user_id').agg({'year': pd.Series.nunique, 'month': pd.Series.nunique})

# filter users for activity in more than one year and/or month
multiple_months_or_years = user_activity[(user_activity['year'] > 1) | (user_activity['month'] > 1)]

multiple_months_or_years
# Out:
#          year  month
# user_id
# 35.0        2      6
# 47.0        2      7
# 52.0        2      4
# 53.0        2      4
# 72.0        1      6
# ...       ...    ...
# 77043.0     1      2
# 78004.0     1      2
# 81208.0     1      2
# 87166.0     1      2
# 87631.0     1      2
#
# [4096 rows x 2 columns]

# %%
month_to_number = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
                   'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}

df_cash_req_userid_filled['date_key'] = pd.to_datetime(df_cash_req_userid_filled['year'].astype(str) + '-' + df_cash_req_userid_filled['month'].map(month_to_number).astype(str) + '-01')
df_cash_req_userid_filled
# Sortiere den DataFrame nach dem neuen Schlüssel
df_cash_req_sorted = df_cash_req_userid_filled.sort_values(by=['user_id', 'date_key'])

df_cash_req_sorted
# Out:
#           id  amount      status                     created_at   user_id  \
# 538     1302   100.0    rejected  2020-04-20 15:50:21.187257+00      34.0
# 180      326    90.0    rejected  2019-12-28 04:00:22.349592+00      35.0
# 58       150   100.0    rejected  2019-12-13 20:27:38.106778+00      35.0
# 345      510    90.0    rejected  2020-01-27 19:50:46.387431+00      35.0
# 91       758    90.0    rejected   2020-02-28 10:51:11.44088+00      35.0
# ...      ...     ...         ...                            ...       ...
# 10893  26992   100.0  money_back  2020-11-01 20:31:53.965482+00  103425.0
# 23389  26984   100.0  money_back  2020-11-01 19:35:00.540424+00  103437.0
# 18752  26983   100.0  money_back    2020-11-01 19:30:26.4344+00  103496.0
# 19324  26989    50.0  money_back  2020-11-01 20:12:26.857203+00  103503.0
# 22005  27005   100.0  money_back  2020-11-01 23:06:44.582445+00  103719.0
#
#        deleted_account_id transfer_type month  year   date_key
# ...

# %%
# define cohort for user regarding to the key_date (first Cash Request)
cohort = df_cash_req_sorted.groupby('user_id').first().reset_index()

# Print the cohort in the new column
df_cash_req_sorted['cohort'] = df_cash_req_sorted['user_id'].map(cohort.set_index('user_id')['date_key'])

df_cash_req_sorted
# Out:
#           id  amount      status                     created_at   user_id  \
# 538     1302   100.0    rejected  2020-04-20 15:50:21.187257+00      34.0
# 180      326    90.0    rejected  2019-12-28 04:00:22.349592+00      35.0
# 58       150   100.0    rejected  2019-12-13 20:27:38.106778+00      35.0
# 345      510    90.0    rejected  2020-01-27 19:50:46.387431+00      35.0
# 91       758    90.0    rejected   2020-02-28 10:51:11.44088+00      35.0
# ...      ...     ...         ...                            ...       ...
# 10893  26992   100.0  money_back  2020-11-01 20:31:53.965482+00  103425.0
# 23389  26984   100.0  money_back  2020-11-01 19:35:00.540424+00  103437.0
# 18752  26983   100.0  money_back    2020-11-01 19:30:26.4344+00  103496.0
# 19324  26989    50.0  money_back  2020-11-01 20:12:26.857203+00  103503.0
# 22005  27005   100.0  money_back  2020-11-01 23:06:44.582445+00  103719.0
#
#        deleted_account_id transfer_type month  year   date_key     cohort
# ...

# %%
user_per_cohort = df_cash_req_sorted.groupby("cohort")["user_id"].nunique()
user_per_cohort
# Out:
# cohort
# 2019-11-01       1
# 2019-12-01     254
# 2020-01-01     106
# 2020-02-01      90
# 2020-03-01      86
# 2020-04-01     246
# 2020-05-01     432
# 2020-06-01    1540
# 2020-07-01    1482
# 2020-08-01     728
# 2020-09-01    1950
# 2020-10-01    4802
# 2020-11-01      76
# Name: user_id, dtype: int64

# %%
usage_per_cohort = df_cash_req_sorted["cohort"].value_counts()
usage_per_cohort
# Out:
# cohort
# 2020-06-01    5266
# 2020-10-01    5058
# 2020-07-01    4147
# 2020-09-01    2925
# 2020-05-01    1660
# 2020-08-01    1632
# 2019-12-01    1080
# 2020-04-01     952
# 2020-02-01     441
# 2020-03-01     371
# 2020-01-01     354
# 2020-11-01      76
# 2019-11-01       8
# Name: count, dtype: int64

# %%
average_usage_per_user = usage_per_cohort / user_per_cohort
average_usage_per_user
# Out:
# cohort
# 2019-11-01    8.000000
# 2019-12-01    4.251969
# 2020-01-01    3.339623
# 2020-02-01    4.900000
# 2020-03-01    4.313953
# 2020-04-01    3.869919
# 2020-05-01    3.842593
# 2020-06-01    3.419481
# 2020-07-01    2.798246
# 2020-08-01    2.241758
# 2020-09-01    1.500000
# 2020-10-01    1.053311
# 2020-11-01    1.000000
# Freq: MS, dtype: float64

# %%
cohort_table = pd.concat([user_per_cohort, usage_per_cohort, average_usage_per_user], axis=1)
cohort_table.columns = ['Users', 'Frequency of usage', 'Average usage per user']
cohort_table
# Out:
#             Users  Frequency of usage  Average usage per user
# cohort
# 2019-11-01      1                   8                8.000000
# 2019-12-01    254                1080                4.251969
# 2020-01-01    106                 354                3.339623
# 2020-02-01     90                 441                4.900000
# 2020-03-01     86                 371                4.313953
# 2020-04-01    246                 952                3.869919
# 2020-05-01    432                1660                3.842593
# 2020-06-01   1540                5266                3.419481
# 2020-07-01   1482                4147                2.798246
# 2020-08-01    728                1632                2.241758
# 2020-09-01   1950                2925                1.500000
# 2020-10-01   4802                5058                1.053311
# 2020-11-01     76                  76                1.000000

# %%
sns.barplot(data=cohort_table, y = "Cohort", x = "Users", palette="Blues")
#plt.rcParams.update({'font.size':18})
plt.title('Users per Cohort')
plt.show()
# Out:
# /var/folders/1m/50y9vknn1lx05wgwhbgqtdh80000gn/T/ipykernel_9617/4019437959.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cohort_table, y = "cohort", x = "Users", palette="Blues")

# %%
sns.barplot(data=cohort_table, y = "cohort", x = "Frequency of usage", palette="Blues")
#plt.rcParams.update({'font.size':18})
plt.title('Usage per cohort')
plt.show()
# Out:
# /var/folders/1m/50y9vknn1lx05wgwhbgqtdh80000gn/T/ipykernel_9617/1170394593.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cohort_table, y = "cohort", x = "Frequency of usage", palette="Blues")

# %%
sns.barplot(data=cohort_table, y = "cohort", x = "Average usage per user", palette="Blues")
#plt.rcParams.update({'font.size':18})
plt.title('User Activity')
plt.show()
# Out:
# /var/folders/1m/50y9vknn1lx05wgwhbgqtdh80000gn/T/ipykernel_9617/4093270294.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cohort_table, y = "cohort", x = "Average usage per user", palette="Blues")
